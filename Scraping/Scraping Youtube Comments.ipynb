# %%
dev = "AIzaSyBIk_Ff7W0BsM01x95H2bkYgDEb8oZSZHE"

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="C2aZPjVdqyA",
    maxResults=56553
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="-GJgqIJsTME", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      783 non-null    object
#  1   updated_at  783 non-null    object
#  2   like_count  783 non-null    int64
#  3   text        783 non-null    object
#  4   public      783 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 25.4+ KB

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'NuRIiNCCu-5fH3LmpO_tltFd4jg',
#  'id': 'UgyoKa0f0C9Xw56GuXl4AaABAg',
#  'snippet': {'channelId': 'UC2utQmYluWGlhV-W0rTA2wg',
#   'videoId': '-GJgqIJsTME',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'Y5vfYGYbyEU2MtcztevoQjvQ4WE',
#    'id': 'UgyoKa0f0C9Xw56GuXl4AaABAg',
#    'snippet': {'channelId': 'UC2utQmYluWGlhV-W0rTA2wg',
#     'videoId': '-GJgqIJsTME',
#     'textDisplay': 'Awesome FCUK,  stay in France 🇫🇷 and show one episode everyday. 🍷😋😋😀😀',
#     'textOriginal': 'Awesome FCUK,  stay in France 🇫🇷 and show one episode everyday. 🍷😋😋😀😀',
#     'authorDisplayName': '@sunilpatel217',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIf8zZSGHIdbdio5k7rJX_q6qY0F-CBjQNYzcC4VVQ=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@sunilpatel217',
#     'authorChannelId': {'value': 'UCLz2RaPJGdC1d2Gf6Yl5jug'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2023-10-23T16:20:55Z',
#     'updatedAt': '2023-10-23T16:20:55Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.head(1485)
# Out:
#                               author            updated_at  like_count  \
# 0                         @mnmnmn412  2024-02-11T09:07:47Z           0
# 1                   @galpam_vlog3092  2024-02-10T11:26:23Z           0
# 2               @astisitipratiwi9266  2024-02-10T03:05:46Z           0
# 3                         @jawanegro  2024-02-08T17:14:53Z           2
# 4                         @jawanegro  2024-02-08T17:08:57Z           1
# ..                               ...                   ...         ...
# 778                      @SamB-ij1ko  2023-10-23T13:34:13Z           0
# 779                          @ec6678  2023-10-23T13:33:21Z          13
# 780                       @cheng8841  2023-10-23T12:57:26Z          68
# 781                   @BigTunaBoy420  2023-10-23T12:30:09Z         275
# 782  @cccccccccccccccccccccccccc8412  2023-10-23T12:30:02Z           0
#
#                                                   text  public
# 0    1:36:43 refleksi AB 1:37:12\n4:20:47 refleksi ...    True
# 1                                 Pecahh pak prabowo😍😍    True
# 2    Coba yg ditanya ga cuma capres tp wakil nya ju...    True
# 3                                    5:31:49 ini nih 🤫    True
# 4    Di menit brp sih yg Prabowo bilang aset mandek...    True
# ..                                                 ...     ...
# 778                                   Buzzing for this    True
# 779                       Watch out for those bed bugs    True
# 780                   "eight part series" LETS GOOOOOO    True
# 781    One of the best and most authentic eating shows    True
# 782                                              First    True
#
# [783 rows x 5 columns]

# %%
df.sort_values(by='like_count', ascending=False)[0:100]
# Out:
#                   author            updated_at  like_count  \
# 767          @dirtsmegee  2023-10-23T15:05:54Z        1073
# 670       @Nolanbrown480  2023-10-23T16:59:12Z         725
# 635  @ActionBronsonMusic  2023-10-23T17:53:02Z         589
# 772      @uknownutin3528  2023-10-23T15:01:03Z         524
# 781       @BigTunaBoy420  2023-10-23T12:30:09Z         275
# ..                   ...                   ...         ...
# 587    @happythoughts700  2023-10-23T20:12:00Z           1
# 211      @brianperez1563  2023-10-27T21:08:45Z           1
# 299              @Lpm920  2023-10-25T22:40:02Z           1
# 586        @604Anonymous  2023-10-23T20:15:10Z           1
# 597    @MetallFistGuitar  2023-10-23T19:36:18Z           1
#
#                                                   text  public
# 767  Action needs an 8 part series in every country...    True
# 670  Clovis’ energy is absolutely unmatched. The pe...    True
# 635                                  PARIS. WITH LOVE.    True
# 772  One of the best food series on YouTube. LONG L...    True
# 781    One of the best and most authentic eating shows    True
# ..                                                 ...     ...
# 587  NO FUCKING WAY THIS ACTUALLY HAPPENED BROOOOOO...    True
# 211  From Paris with love is back! Clovis is a fuck...    True
# 299  Don’t get it twisted.  They love Americans in ...    True
# 586  Love how he's transition from mainly rapping t...    True
# 597                                            LOVE <3    True
#
# [100 rows x 5 columns]

# %%
df.to_csv("dataset.csv",sep=";")
